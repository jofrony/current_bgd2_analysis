# %%
import os
from snudda.plotting.Blender.visualisation.visualise_network import VisualiseNetwork

# %%
local = os.path.join("/home", "jofrony", "Documents", "Repositories", "current_bgd2", 
                     "network_visualisation", "local", "analysis", "visualisation") 
network_path = os.path.join(local, "networks/striatum")

# %%
# %%time
blender_output_image = os.path.join(network_path, "neuron-rendering.png")

vn = VisualiseNetwork(network_path=network_path, blender_output_image=blender_output_image)
vn.visualise(blender_output_image=blender_output_image, show_synapses=False)
# Out:
# Loading 50 neurons with 1691 synapses and 0 gap junctions
# Cleaning the scene.
# Info: Deleted 3 object(s)
# /home/jofrony/Dropbox/Repositories/BasalGangliaData/data/neurons/striatum/ispn/str-ispn-e150917_c11_D2-mWT-MSN1-v20211026/morphology/WT-MSN1-cor-rep-ax-res3-var8.swc
# Adding soma [1.0, 0.0, 0.0, 0.0, 5.61785, -1]
# Setting neuron 0 (iSPN_1) position: [0.00470278 0.00394067 0.00769257]
# Color......
# /home/jofrony/Dropbox/Repositories/BasalGangliaData/data/neurons/striatum/fs/str-fs-e161024_FS16-mDR-rat-Mar-13-08-1-536-R-v20210210/morphology/DR-rat-Mar-13-08-1-536-R-cor-rep-res3-var4.swc
# Adding soma [1.0, 0.0, 0.0, 0.0, 5.7253, -1]
# Setting neuron 1 (FS_1) position: [0.0047161  0.00394076 0.00770437]
# Color......
# /home/jofrony/Dropbox/Repositories/BasalGangliaData/data/neurons/striatum/ispn/str-ispn-e160118_c10_D2-m46-3-DE-v20211026/morphology/46-3-DE-cor-rep-ax-res3-var1.swc
# Adding soma [1.0, 0.0, 0.0, 0.0, 6.52456, -1]
# Setting neuron 2 (iSPN_3) position: [0.00472377 0.00392535 0.00770389]
# Color......
# /home/jofrony/Dropbox/Repositories/BasalGangliaData/data/neurons/striatum/ispn/str-ispn-e150908_c4_D2-m51-5-DE-v20211026/morphology/51-5-DE-cor-rep-ax-res3-var0.swc
# Adding soma [1.0, 0.0, 0.0, 0.0, 6.74395, -1]
# Setting neuron 3 (iSPN_0) position: [0.0047183  0.00393932 0.00772094]
# Color......
# Setting neuron 4 (iSPN_0) position: [0.00470074 0.00397254 0.00768405]
# Color......
# /home/jofrony/Dropbox/Repositories/BasalGangliaData/data/neurons/striatum/dspn/str-dspn-e150602_c1_D1-mWT-0728MSN01-v20211026/morphology/WT-0728MSN01-cor-rep-ax-res3-var1.swc
# Adding soma [1.0, 0.0, 0.0, 0.0, 6.49, -1]
# Setting neuron 5 (dSPN_0) position: [0.00469772 0.00397023 0.00770996]
# Color......
# Setting neuron 6 (iSPN_0) position: [0.00473523 0.00395733 0.00769965]
# Color......
# /home/jofrony/Dropbox/Repositories/BasalGangliaData/data/neurons/striatum/ispn/str-ispn-e151123_c1_D2-mWT-P270-09-v20211026/morphology/WT-P270-09-15ak-cor-res3-var5.swc
# Adding soma [1.0, 0.0, 0.0, 0.0, 7.47495, -1]
# Setting neuron 7 (iSPN_2) position: [0.00469831 0.00394785 0.00773404]
# Color......
# Setting neuron 8 (iSPN_2) position: [0.00474069 0.00396    0.00768151]
# Color......
# Setting neuron 9 (iSPN_2) position: [0.00473003 0.00392738 0.0077264 ]
# Color......
# /home/jofrony/Dropbox/Repositories/BasalGangliaData/data/neurons/striatum/dspn/str-dspn-e150917_c9_D1-mWT-1215MSN03-v20211026/morphology/WT-1215MSN03-cor-rep-ax-res3-var5.swc
# Adding soma [1.0, 0.0, 0.0, 0.0, 5.3693, -1]
# Setting neuron 10 (dSPN_3) position: [0.00473416 0.00396717 0.00771357]
# Color......
# /home/jofrony/Dropbox/Repositories/BasalGangliaData/data/neurons/striatum/dspn/str-dspn-e150917_c10_D1-mWT-P270-20-v20211026/morphology/WT-P270-20-15ak-cor-res3-var0.swc
# Adding soma [1.0, 0.0, 0.0, 0.0, 6.37456, -1]
# Setting neuron 11 (dSPN_1) position: [0.0047137  0.00397314 0.00772515]
# Color......
# Setting neuron 12 (iSPN_1) position: [0.00474883 0.00394951 0.00770732]
# Color......
# /home/jofrony/Dropbox/Repositories/BasalGangliaData/data/neurons/striatum/dspn/str-dspn-e150917_c6_D1-m21-6-DE-v20211028/morphology/21-6-DE-cor-rep-ax-res3-var0.swc
# Adding soma [1.0, 0.0, 0.0, 0.0, 7.64492, -1]
# Setting neuron 13 (dSPN_2) position: [0.00469901 0.00397432 0.00773025]
# Color......
# Setting neuron 14 (iSPN_2) position: [0.00473724 0.00397767 0.0076983 ]
# Color......
# Setting neuron 15 (dSPN_1) position: [0.00475242 0.00393146 0.0076818 ]
# Color......
# Setting neuron 16 (dSPN_0) position: [0.00474689 0.00395928 0.00772172]
# Color......
# Setting neuron 17 (dSPN_1) position: [0.00475872 0.00394493 0.00769048]
# Color......
# Setting neuron 18 (dSPN_0) position: [0.00473059 0.00399069 0.00770401]
# Color......
# Setting neuron 19 (iSPN_3) position: [0.00471456 0.00399307 0.00771835]
# Color......
# Setting neuron 20 (dSPN_0) position: [0.00472605 0.00393124 0.0077498 ]
# Color......
# Setting neuron 21 (iSPN_0) position: [0.00471001 0.00394017 0.00775506]
# Color......
# Setting neuron 22 (dSPN_3) position: [0.00476592 0.00392865 0.00769462]
# Color......
# Setting neuron 23 (dSPN_3) position: [0.00475289 0.0039812  0.00769202]
# Color......
# Setting neuron 24 (iSPN_3) position: [0.00476317 0.00396555 0.00769127]
# Color......
# Setting neuron 25 (iSPN_0) position: [0.00473485 0.00397892 0.00773506]
# Color......
# Setting neuron 26 (iSPN_1) position: [0.00470165 0.00395436 0.00775754]
# Color......
# Setting neuron 27 (iSPN_1) position: [0.00475873 0.00397442 0.00767896]
# Color......
# Setting neuron 28 (iSPN_3) position: [0.00469485 0.00393835 0.00775967]
# Color......
# Setting neuron 29 (dSPN_1) position: [0.00475792 0.00393806 0.00773219]
# Color......
# Setting neuron 30 (dSPN_2) position: [0.00472487 0.00400534 0.00769316]
# Color......
# Setting neuron 31 (dSPN_1) position: [0.00474736 0.00396998 0.00773874]
# Color......
# Setting neuron 32 (dSPN_2) position: [0.0047442  0.00395441 0.00774994]
# Color......
# Setting neuron 33 (dSPN_0) position: [0.00470119 0.0039828  0.00775194]
# Color......
# Setting neuron 34 (dSPN_2) position: [0.00476514 0.00395251 0.00772976]
# Color......
# Setting neuron 35 (iSPN_2) position: [0.00472572 0.00396902 0.00775804]
# Color......
# Setting neuron 36 (dSPN_3) position: [0.00474712 0.00398912 0.00773552]
# Color......
# Setting neuron 37 (iSPN_0) position: [0.00469938 0.00400937 0.00773046]
# Color......
# Setting neuron 38 (iSPN_1) position: [0.00477086 0.00398078 0.00769695]
# Color......
# Setting neuron 39 (iSPN_3) position: [0.00477798 0.00395144 0.0077165 ]
# Color......
# Setting neuron 40 (dSPN_2) position: [0.00471494 0.00400473 0.00773985]
# Color......
# Setting neuron 41 (iSPN_3) position: [0.00476051 0.00399776 0.00769302]
# Color......
# Setting neuron 42 (iSPN_1) position: [0.00475692 0.00393131 0.00775446]
# Color......
# Setting neuron 43 (dSPN_3) position: [0.00476882 0.00393746 0.00774499]
# Color......
# Setting neuron 44 (dSPN_1) position: [0.00477735 0.00395151 0.00773907]
# Color......
# Setting neuron 45 (dSPN_0) position: [0.00473593 0.00398593 0.00776234]
# Color......
# Setting neuron 46 (dSPN_3) position: [0.00471407 0.00400934 0.00775575]
# Color......
# Setting neuron 47 (iSPN_2) position: [0.00475237 0.00398775 0.00775835]
# Color......
# Setting neuron 48 (dSPN_2) position: [0.00477644 0.00398009 0.00774729]
# Color......
# /home/jofrony/Dropbox/Repositories/BasalGangliaData/data/neurons/striatum/chin/str-chin-e170614_cell6-m17JUL301751_170614_no6_MD_cell_1_x63-v20190710/morphology/optim_chin_morph_renamed2019-11-08.swc
# Adding soma [1.0, 0.0, 0.0, 0.0, 9.012, -1]
# Setting neuron 49 (ChIN_0) position: [0.0047741  0.00400891 0.00770889]
# Color......
# (  0.0001 sec |   0.0001 sec) Importing OBJ '/home/jofrony/Documents/Repositories/current_bgd2/network_visualisation/local/analysis/visualisation/networks/striatum/mesh/Striatum-cube-mesh-8.532141342733388e-05.obj'...
#   (  0.0010 sec |   0.0005 sec) Parsing OBJ file...
#     (  0.0017 sec |   0.0004 sec) Done, loading materials and images...
#     (  0.0040 sec |   0.0027 sec) Done, building geometries (verts:8 faces:12 materials: 1 smoothgroups:0) ...
#     (  1.2301 sec |   1.2288 sec) Done.
#   (  1.2306 sec |   1.2301 sec) Finished importing: '/home/jofrony/Documents/Repositories/current_bgd2/network_visualisation/local/analysis/visualisation/networks/striatum/mesh/Striatum-cube-mesh-8.532141342733388e-05.obj'
# Progress: 100.00%
#
# [bpy.data.objects['Camera']]
# Info: Saved "visualise-network.blend"
# Rendering image.
# CPU times: user 2min 29s, sys: 1.41 s, total: 2min 30s
# Wall time: 1min 20s

# %%
import os
from snudda.plotting.Blender.visualisation.visualise_network import VisualiseNetwork

network_path = os.path.join("networks","simple_example")
blender_output_image = os.path.join(network_path, "neuron-rendering.png")

vn = VisualiseNetwork(network_path=network_path, 
                      network_json=os.path.join(network_path, "network-synapses.json"),
                      blender_output_image=blender_output_image)
vn.visualise(neuron_id=[0,7])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-af67a62e30b5> in <module>
#       7 vn = VisualiseNetwork(network_path=network_path,
#       8                       network_json=os.path.join(network_path, "network-synapses.json"),
# ----> 9                       blender_output_image=blender_output_image)
#      10 vn.visualise(neuron_id=[0,7])
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/snudda/plotting/Blender/visualisation/visualise_network.py in __init__(self, network_path, blender_save_file, blender_output_image, network_json, simulation_output_file_name)
#      51             from snudda.utils.fake_load import FakeLoad
#      52             self.sl = FakeLoad()
# ---> 53             self.sl.import_json(self.network_json)
#      54             self.data = self.sl.data
#      55
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/snudda/utils/fake_load.py in import_json(self, json_file_name)
#      37     def import_json(self, json_file_name):
#      38
# ---> 39         with open(json_file_name, "r") as f:
#      40             self.data = json.load(f, object_pairs_hook=OrderedDict)
#      41
#
# FileNotFoundError: [Errno 2] No such file or directory: 'networks/simple_example/network-synapses.json'

# %%
from IPython.display import Image
Image(blender_output_image)
