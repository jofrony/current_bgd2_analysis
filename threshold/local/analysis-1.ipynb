# %%
import h5py
import os
import matplotlib.pyplot as plt

# %%
hdf = h5py.File(os.path.join("networks", "striatum", "simulation", "voltage_clamp_out_trial.hdf5"), "r")

# %%
plt.plot(hdf['i_save_0'][:][0][50:])
