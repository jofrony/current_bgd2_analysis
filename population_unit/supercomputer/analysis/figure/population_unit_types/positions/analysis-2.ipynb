# %%
import sys
import os
sys.path.append(os.environ["CODE_REPOSITORY"])
from code_repository.hotones.thetools import *
from snudda.utils.load import SnuddaLoad

# %% [markdown]
# # Complete-random-type population unit

# %% [markdown]
# ### Percentage 12.5%

# %%
external = os.path.join("/media","jofrony","2TB","dardel", "current_bgd2","population_unit", "complete_network", 
                        "supercomputer", "networks", "pdc_network_2022-08-31-p0125")
network_path = os.path.join(external,"network-synapses.hdf5")

# %%
network_data = SnuddaLoad(network_file=network_path)
# Out:
# Loading 40000 neurons with 35040256 synapses and 2531 gap junctions

# %%
neuron_types = network_data.get_neuron_types()
soma_positions = network_data.data["neuronPositions"]
population_units = network_data.data["populationUnit"]
population_unit_colour = {0: "grey", 1 : "red", 2: "blue"}
remove_grids = True
step_size = 10
scale_position_x = 5.2e-3

# %%
# %%time
plot_position_3D(soma_positions=soma_positions, 
                     neuron_types=neuron_types, 
                     colour=striatum_colour_code, 
                     remove_grids=remove_grids,
                     step_size=step_size,
                     scale_position_x=scale_position_x)
# Out:
# CPU times: user 1min 19s, sys: 909 ms, total: 1min 20s
# Wall time: 1min 19s

# %%
# %%time
plot_position_3D(soma_positions=soma_positions, 
                     neuron_types=neuron_types, 
                     colour=striatum_colour_code_rgb, 
                     remove_grids=remove_grids,
                     step_size=step_size,
                     scale_position_x=scale_position_x)
# Out:
# CPU times: user 1min 16s, sys: 448 ms, total: 1min 17s
# Wall time: 1min 16s

# %%
# %%time
plot_position_3D_population_unit(soma_positions=soma_positions, 
                     population_units=population_units, 
                     colour=population_unit_colour, 
                     remove_grids=remove_grids,
                     step_size=step_size,
                     scale_position_x=scale_position_x)
# Out:
# CPU times: user 3min 53s, sys: 660 ms, total: 3min 53s
# Wall time: 3min 53s

# %%
### Percentage 25%

# %%
external = os.path.join("/media","jofrony","2TB","dardel", "current_bgd2","population_unit", "complete_network", 
                        "supercomputer", "networks", "pdc_network_2022-08-31-p025")
network_path = os.path.join(external,"network-synapses.hdf5")

# %%
network_data = SnuddaLoad(network_file=network_path)
# Out:
# Loading 40000 neurons with 35040256 synapses and 2531 gap junctions

# %%
neuron_types = network_data.get_neuron_types()
soma_positions = network_data.data["neuronPositions"]
population_units = network_data.data["populationUnit"]
population_unit_colour = {0: "grey", 1 : "red", 2: "blue"}
remove_grids = True
step_size = 10
scale_position_x = 5.2e-3

# %%
# %%time
plot_position_3D(soma_positions=soma_positions, 
                     neuron_types=neuron_types, 
                     colour=striatum_colour_code, 
                     remove_grids=remove_grids,
                     step_size=step_size,
                     scale_position_x=scale_position_x)
# Out:
# CPU times: user 1min 17s, sys: 472 ms, total: 1min 17s
# Wall time: 1min 17s

# %%
# %%time
plot_position_3D(soma_positions=soma_positions, 
                     neuron_types=neuron_types, 
                     colour=striatum_colour_code_rgb, 
                     remove_grids=remove_grids,
                     step_size=step_size,
                     scale_position_x=scale_position_x)
# Out:
# CPU times: user 1min 18s, sys: 473 ms, total: 1min 19s
# Wall time: 1min 18s

# %%
# %%time
plot_position_3D_population_unit(soma_positions=soma_positions, 
                     population_units=population_units, 
                     colour=population_unit_colour, 
                     remove_grids=remove_grids,
                     step_size=step_size,
                     scale_position_x=scale_position_x)
# Out:
# CPU times: user 7min 1s, sys: 606 ms, total: 7min 1s
# Wall time: 7min 1s

# %%
### Percentage 50%

# %%
external = os.path.join("/media","jofrony","2TB","dardel", "current_bgd2","population_unit", "complete_network", 
                        "supercomputer", "networks", "pdc_network_2022-08-31-p05")
network_path = os.path.join(external,"network-synapses.hdf5")

# %%
network_data = SnuddaLoad(network_file=network_path)
# Out:
# Loading 40000 neurons with 35040256 synapses and 2531 gap junctions

# %%
neuron_types = network_data.get_neuron_types()
soma_positions = network_data.data["neuronPositions"]
population_units = network_data.data["populationUnit"]
population_unit_colour = {0: "grey", 1 : "red", 2: "blue"}
remove_grids = True
step_size = 10
scale_position_x = 5.2e-3

# %%
# %%time
plot_position_3D(soma_positions=soma_positions, 
                     neuron_types=neuron_types, 
                     colour=striatum_colour_code, 
                     remove_grids=remove_grids,
                     step_size=step_size,
                     scale_position_x=scale_position_x)
# Out:
# CPU times: user 1min 22s, sys: 492 ms, total: 1min 23s
# Wall time: 1min 22s

# %%
# %%time
plot_position_3D(soma_positions=soma_positions, 
                     neuron_types=neuron_types, 
                     colour=striatum_colour_code_rgb, 
                     remove_grids=remove_grids,
                     step_size=step_size,
                     scale_position_x=scale_position_x)
# Out:
# CPU times: user 1min 23s, sys: 464 ms, total: 1min 24s
# Wall time: 1min 23s

# %%
# %%time
plot_position_3D_population_unit(soma_positions=soma_positions, 
                     population_units=population_units, 
                     colour=population_unit_colour, 
                     remove_grids=remove_grids,
                     step_size=step_size,
                     scale_position_x=scale_position_x)
# Out:
# CPU times: user 13min 24s, sys: 1.05 s, total: 13min 25s
# Wall time: 13min 24s
