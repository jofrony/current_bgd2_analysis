# %%
import sys
import os
sys.path.append(os.environ["CODE_REPOSITORY"])
from code_repository.hotones.thetools import *
from snudda.utils.load import SnuddaLoad

# %% [markdown]
# # Complete-distance population unit

# %% [markdown]
# ### Distance 0

# %%
external = os.path.join("/media","jofrony","2TB","dardel", "current_bgd2","population_unit", "distance_complete", 
                        "supercomputer", "networks", "pdc_network_2022-10-14")
network_path = os.path.join(external,"network-synapses.hdf5")

# %%
network_data = SnuddaLoad(network_file=network_path)
# Out:
# Loading 40000 neurons with 35040256 synapses and 2531 gap junctions

# %%
neuron_types = network_data.get_neuron_types()
soma_positions = network_data.data["neuronPositions"]
population_units = network_data.data["populationUnit"]
population_unit_colour = {0: "grey", 1 : "red", 2: "blue"}
remove_grids = True
step_size = 10
scale_position_x = 5.2e-3

# %%
# %%time
plot_position_3D(soma_positions=soma_positions, 
                     neuron_types=neuron_types, 
                     colour=striatum_colour_code, 
                     remove_grids=remove_grids,
                     step_size=step_size,
                     scale_position_x=scale_position_x)
# Out:
# CPU times: user 1min 28s, sys: 1.08 s, total: 1min 30s
# Wall time: 1min 29s

# %%
# %%time
plot_position_3D(soma_positions=soma_positions, 
                     neuron_types=neuron_types, 
                     colour=striatum_colour_code_rgb, 
                     remove_grids=remove_grids,
                     step_size=step_size,
                     scale_position_x=scale_position_x)
# Out:
# CPU times: user 1min 19s, sys: 429 ms, total: 1min 20s
# Wall time: 1min 19s

# %%
# %%time
plot_position_3D_population_unit(soma_positions=soma_positions, 
                     population_units=population_units, 
                     colour=population_unit_colour, 
                     remove_grids=remove_grids,
                     step_size=step_size,
                     scale_position_x=scale_position_x)
# Out:
# CPU times: user 3min 55s, sys: 709 ms, total: 3min 56s
# Wall time: 3min 55s

# %% [markdown]
# ### Distance 45

# %%
external = os.path.join("/media","jofrony","2TB","dardel", "current_bgd2","population_unit", "distance_complete", 
                        "supercomputer", "networks", "pdc_network_2022-10-13")
network_path = os.path.join(external,"network-synapses.hdf5")

# %%
network_data = SnuddaLoad(network_file=network_path)
# Out:
# Loading 40000 neurons with 35040256 synapses and 2531 gap junctions

# %%
neuron_types = network_data.get_neuron_types()
soma_positions = network_data.data["neuronPositions"]
population_units = network_data.data["populationUnit"]
population_unit_colour = {0: "grey", 1 : "red", 2: "blue"}
remove_grids = True
step_size = 10
scale_position_x = 5.2e-3

# %%
# %%time
plot_position_3D(soma_positions=soma_positions, 
                     neuron_types=neuron_types, 
                     colour=striatum_colour_code, 
                     remove_grids=remove_grids,
                     step_size=step_size,
                     scale_position_x=scale_position_x)
# Out:
# CPU times: user 1min 18s, sys: 484 ms, total: 1min 18s
# Wall time: 1min 18s

# %%
# %%time
plot_position_3D(soma_positions=soma_positions, 
                     neuron_types=neuron_types, 
                     colour=striatum_colour_code_rgb, 
                     remove_grids=remove_grids,
                     step_size=step_size,
                     scale_position_x=scale_position_x)
# Out:
# CPU times: user 1min 24s, sys: 460 ms, total: 1min 25s
# Wall time: 1min 24s

# %%
# %%time
plot_position_3D_population_unit(soma_positions=soma_positions, 
                     population_units=population_units, 
                     colour=population_unit_colour, 
                     remove_grids=remove_grids,
                     step_size=step_size,
                     scale_position_x=scale_position_x)
# Out:
# CPU times: user 4min 2s, sys: 533 ms, total: 4min 3s
# Wall time: 4min 2s

# %% [markdown]
# ### Distance 90

# %%
external = os.path.join("/media","jofrony","2TB","dardel", "current_bgd2","population_unit", "distance_complete", 
                        "supercomputer", "networks", "pdc_network_2022-10-10")
network_path = os.path.join(external,"network-synapses.hdf5")

# %%
network_data = SnuddaLoad(network_file=network_path)
# Out:
# Loading 40000 neurons with 35040256 synapses and 2531 gap junctions

# %%
neuron_types = network_data.get_neuron_types()
soma_positions = network_data.data["neuronPositions"]
population_units = network_data.data["populationUnit"]
population_unit_colour = {0: "grey", 1 : "red", 2: "blue"}
remove_grids = True
step_size = 10
scale_position_x = 5.2e-3

# %%
# %%time
plot_position_3D(soma_positions=soma_positions, 
                     neuron_types=neuron_types, 
                     colour=striatum_colour_code, 
                     remove_grids=remove_grids,
                     step_size=step_size,
                     scale_position_x=scale_position_x)
# Out:
# CPU times: user 1min 19s, sys: 457 ms, total: 1min 19s
# Wall time: 1min 19s

# %%
# %%time
plot_position_3D(soma_positions=soma_positions, 
                     neuron_types=neuron_types, 
                     colour=striatum_colour_code_rgb, 
                     remove_grids=remove_grids,
                     step_size=step_size,
                     scale_position_x=scale_position_x)
# Out:
# CPU times: user 1min 20s, sys: 444 ms, total: 1min 20s
# Wall time: 1min 20s

# %%
# %%time
plot_position_3D_population_unit(soma_positions=soma_positions, 
                     population_units=population_units, 
                     colour=population_unit_colour, 
                     remove_grids=remove_grids,
                     step_size=step_size,
                     scale_position_x=scale_position_x)
# Out:
# CPU times: user 3min 52s, sys: 524 ms, total: 3min 53s
# Wall time: 3min 52s
