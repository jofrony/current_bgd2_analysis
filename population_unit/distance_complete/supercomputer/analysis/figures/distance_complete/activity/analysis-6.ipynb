# %%
import sys
import os
sys.path.append(os.environ["CODE_REPOSITORY"])
from code_repository.hotones.thetools import *
from snudda.utils.load import SnuddaLoad

# %%
external = os.path.join("/media","jofrony", "2TB", "dardel","current_bgd2","population_unit", 
                        "distance_complete", "supercomputer", "networks")

# %%
folder = "voltage_traces"

# %%
e = Experiments()
e.add_experiment(name="p1",
                 color="black",
                 label="2500 ms stimulation",
                 network="network-synapses.hdf5",
                 path=os.path.join(external, "pdc_network_2022-10-14"),
                 output="network_output_network-synapses_cell_ids_current_injection_dardel_2022-10-29-17-34-15_p1-diff_dopamine_modulation_with_receptors_method_alpha_background_tstart_300_tonic_0.2_gmax_increase_0.8_tau_500.hdf5")
e.add_experiment(name="p1_p2",
                 color="red",
                 label="2500 ms stimulation",
                 network="network-synapses.hdf5",
                 path=os.path.join(external, "pdc_network_2022-10-14"),
                 output="network_output_network-synapses_cell_ids_current_injection_dardel_2022-10-29-17-34-15_p1_p2-diff_dopamine_modulation_with_receptors_method_alpha_background_tstart_300_tonic_0.2_gmax_increase_0.8_tau_500.hdf5")

# %%
sl = LoadSimulations(experiments=e)
sl.load_network_file(load_synapses=False)
# Out:
# Loading 40000 neurons with 35040256 synapses and 2531 gap junctions
# Loading /media/jofrony/2TB/dardel/current_bgd2/population_unit/distance_complete/supercomputer/networks/pdc_network_2022-10-14/simulation/network_output_network-synapses_cell_ids_current_injection_dardel_2022-10-29-17-34-15_p1-diff_dopamine_modulation_with_receptors_method_alpha_background_tstart_300_tonic_0.2_gmax_increase_0.8_tau_500.hdf5
# Loading 40000 neurons with 35040256 synapses and 2531 gap junctions
# Loading /media/jofrony/2TB/dardel/current_bgd2/population_unit/distance_complete/supercomputer/networks/pdc_network_2022-10-14/simulation/network_output_network-synapses_cell_ids_current_injection_dardel_2022-10-29-17-34-15_p1_p2-diff_dopamine_modulation_with_receptors_method_alpha_background_tstart_300_tonic_0.2_gmax_increase_0.8_tau_500.hdf5

# %%
neuron_type = "dSPN"
specific_trace_ids = sl.get_population_units(neuron_type="dSPN", population_unit=2)

# %%
specific_trace_ids_sample = {k : specific_trace_ids[k][::1000] for k in specific_trace_ids}

# %%
plot_traces(data_obj=sl,
            neuron_type=neuron_type,
            specific_trace_ids=specific_trace_ids_sample,
            show_plot=True,
            differential=False,
            folder=folder)

# %%
neuron_type = "dSPN"
specific_trace_ids = sl.get_population_units(neuron_type="dSPN", population_unit=1)
specific_trace_ids_sample = {k : specific_trace_ids[k][::1000] for k in specific_trace_ids}
plot_traces(data_obj=sl,
            neuron_type=neuron_type,
            specific_trace_ids=specific_trace_ids_sample,
            show_plot=False,
            folder=folder)

# %%
neuron_type = "iSPN"
specific_trace_ids = sl.get_population_units(neuron_type=neuron_type, population_unit=2)
specific_trace_ids_sample = {k : specific_trace_ids[k][::1000] for k in specific_trace_ids}
plot_traces(data_obj=sl,
            neuron_type=neuron_type,
            specific_trace_ids=specific_trace_ids_sample,
            show_plot=True,
            differential=False,
            folder=folder)

# %%
neuron_type = "iSPN"
specific_trace_ids = sl.get_population_units(neuron_type=neuron_type, population_unit=1)
specific_trace_ids_sample = {k : specific_trace_ids[k][::1000] for k in specific_trace_ids}
plot_traces(data_obj=sl,
            neuron_type=neuron_type,
            specific_trace_ids=specific_trace_ids_sample,
            show_plot=False,
            folder=folder)

# %%
neuron_type = "FS"
specific_trace_ids = sl.get_population_units(neuron_type=neuron_type, population_unit=2)
specific_trace_ids_sample = {k : specific_trace_ids[k][::10] for k in specific_trace_ids}
plot_traces(data_obj=sl,
            neuron_type=neuron_type,
            specific_trace_ids=specific_trace_ids_sample,
            show_plot=True,
            differential=False,
            folder=folder)

# %%
neuron_type = "FS"
specific_trace_ids = sl.get_population_units(neuron_type=neuron_type, population_unit=1)
specific_trace_ids_sample = {k : specific_trace_ids[k][::10] for k in specific_trace_ids}
plot_traces(data_obj=sl,
            neuron_type=neuron_type,
            specific_trace_ids=specific_trace_ids_sample,
            show_plot=False,
            folder=folder)
