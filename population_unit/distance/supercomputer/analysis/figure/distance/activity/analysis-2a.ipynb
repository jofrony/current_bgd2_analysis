# %%
import sys
import os
sys.path.append(os.environ["CODE_REPOSITORY"])
from code_repository.hotones.thetools import *
from snudda.utils.load import SnuddaLoad

# %%
external = os.path.join("/media","jofrony", "10TB", "oslo", "dardel","current_bgd","population_unit", "distance", "supercomputer", "networks")

# %%
folder = "percentage"

# %%
e = Experiments()
e.add_experiment(name="0_p1",
                 color="black",
                 label="2500 ms stimulation",
                 network="network-synapses.hdf5",
                 path=os.path.join(external, "pdc_network_2022-04-27"),
                 output="network_output_p1_v2_external-whole-network-2022-04-27-14-46-01.hdf5")
e.add_experiment(name="0_p1_p2",
                 color="red",
                 label="2500 ms stimulation",
                 network="network-synapses.hdf5",
                 path=os.path.join(external, "pdc_network_2022-04-27"),
                 output="network_output_p1_p2_v2_external-whole-network-2022-04-27-14-46-01.hdf5")

# %%
sl = LoadSimulations(experiments=e)
sl.load_network_file(load_synapses=False)
# Out:
# Loading /media/jofrony/10TB/oslo/dardel/current_bgd/population_unit/distance/supercomputer/networks/pdc_network_2022-04-27/simulation/network_output_p1_v2_external-whole-network-2022-04-27-14-46-01.hdf5
# Loading /media/jofrony/10TB/oslo/dardel/current_bgd/population_unit/distance/supercomputer/networks/pdc_network_2022-04-27/simulation/network_output_p1_p2_v2_external-whole-network-2022-04-27-14-46-01.hdf5
# Loading 40000 neurons with 34944478 synapses and 5251 gap junctions
# Loading 40000 neurons with 34944478 synapses and 5251 gap junctions

# %%
neuron_type = "dSPN"
specific_trace_ids = sl.get_population_units(neuron_type="dSPN", population_unit=1)
spiking_analysis_dict = spiking_analysis(data_obj=sl, neuron_type=neuron_type, trace_ids=specific_trace_ids)
# Out:
#  Identifying spiking neurons within the network

# %%
p = calculate_percentage(dictionary=spiking_analysis_dict)
p
# Out:
# {'0_p1': {'spiking': 100.0, 'other': 0.0},
#  '0_p1_p2': {'spiking': 100.0, 'other': 0.0}}

# %%
plot_percentage_spiking(percentage_dict=p, experiment_names=e, fig_name=neuron_type, folder=folder, save=True)
# Out:
# /home/jofrony/Documents/Repositories/code_repository/code_repository/plot/plot_percentage_spiking.py:58: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(np.linspace(0, max_percentage, len(ax.get_xticklabels()), dtype=np.int_), **csfont)

# %%
neuron_type = "iSPN"
specific_trace_ids = sl.get_population_units(neuron_type=neuron_type, population_unit=1)
spiking_analysis_dict = spiking_analysis(data_obj=sl, neuron_type=neuron_type, trace_ids=specific_trace_ids)
# Out:
#  Identifying spiking neurons within the network

# %%
p = calculate_percentage(dictionary=spiking_analysis_dict)
p
# Out:
# {'0_p1': {'spiking': 99.41176470588235, 'other': 0.5882352941176471},
#  '0_p1_p2': {'spiking': 99.41176470588235, 'other': 0.5882352941176471}}

# %%
plot_percentage_spiking(percentage_dict=p, experiment_names=e, fig_name=neuron_type, folder=folder, save=True)
