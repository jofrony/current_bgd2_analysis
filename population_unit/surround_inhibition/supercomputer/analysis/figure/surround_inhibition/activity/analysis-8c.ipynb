# %%
import sys
import json
import os
sys.path.append(os.environ["CODE_REPOSITORY"])
from code_repository.hotones.thetools import *
import matplotlib.pyplot as plt
from snudda.utils.load import SnuddaLoad
import pandas as pd
import seaborn as sns

# %%
external = os.path.join("/media","jofrony","2TB", "dardel","current_bgd2","population_unit", "surround_inhibition", "supercomputer", "networks")

# %%
simulation_repo = os.path.join("/home","jofrony","Dropbox","Repositories","current_bgd2","population_unit","surround_inhibition","supercomputer")

# %%
cell_ids = json.load(open(os.path.join(simulation_repo,"networks", "pdc_network_2022-08-31", "cell_ids_dardel_p1.json")))

# %%
folder = "frequency"

# %%
parameters = {"start": 0.5, "end": 2.5}

# %%
e = Experiments()
e.add_experiment(name="p1_with_ex",
                 color="black",
                 label="2500 ms stimulation",
                 network="network-synapses.hdf5",
                 path=os.path.join(external, "pdc_network_2022-08-31"),
                 output="network_output_external-input-dardel-2022-10-25-12-00-58-p1_empty.hdf5")
e.add_experiment(name="p1_with_ex_current_injection_presynaptic",
                 color="red",
                 label="2500 ms stimulation",
                 network="network-synapses.hdf5",
                 path=os.path.join(external, "pdc_network_2022-08-31"),
                 output="network_output_110mV_external-input-dardel-2022-10-25-12-00-58-p1_cell_ids_current_injection_dardel_2022-12-30-12-53-34_presynaptic_to_p1.hdf5")

# %%
sl = LoadSimulations(experiments=e)
sl.load_network_file(load_synapses=False)
# Out:
# Loading 40000 neurons with 35040256 synapses and 2531 gap junctions
# Loading /media/jofrony/2TB/dardel/current_bgd2/population_unit/surround_inhibition/supercomputer/networks/pdc_network_2022-08-31/simulation/network_output_external-input-dardel-2022-10-25-12-00-58-p1_empty.hdf5
# Loading 40000 neurons with 35040256 synapses and 2531 gap junctions
# Loading /media/jofrony/2TB/dardel/current_bgd2/population_unit/surround_inhibition/supercomputer/networks/pdc_network_2022-08-31/simulation/network_output_110mV_external-input-dardel-2022-10-25-12-00-58-p1_cell_ids_current_injection_dardel_2022-12-30-12-53-34_presynaptic_to_p1.hdf5

# %%
neuron_type="SPN"
specific_trace_ids = {k: cell_ids["iSPN"][::10]+cell_ids["dSPN"] for k in e.experiments}
dt_step=0.5

# %%
# %%time
dendritic_voltage = dendrite_voltage(data_obj=sl, 
                                     neuron_type=neuron_type, 
                                     specific_trace_ids=specific_trace_ids,
                                     interval=[0.1,2.5], 
                                     dt_step=dt_step)

average_dendritic_voltages = average_dendritic_voltage(dvoltage=dendritic_voltage)
# Out:
#   SPN and 187 traces
#   SPN and 187 traces
# CPU times: user 15.9 s, sys: 1.4 s, total: 17.3 s
# Wall time: 36.2 s

# %%
experiments = sl.get_experiment_names()

# %%
common_per_experiment = specific_trace_ids["p1_with_ex"]

# %%
data_per_experiment = {e_name: sl.get_data(name=e_name) for e_name in experiments}

# %%
cs = {"p1_with_ex": 'black', 
      "p1_with_ex_current_injection_presynaptic": 'red'}

# %%
parameters = {"start": 0.5, "end": 2.5}

# %%
neuron_type = "dSPN"
specific_trace_ids = sl.get_population_units(neuron_type=neuron_type, population_unit=1)
frequency_analysis_dict_dspn = frequency_analysis(data_obj=sl, neuron_type=neuron_type, trace_ids=specific_trace_ids, parameters=parameters)

# %%
neuron_type = "iSPN"
specific_trace_ids = sl.get_population_units(neuron_type=neuron_type, population_unit=1)
frequency_analysis_dict_ispn = frequency_analysis(data_obj=sl, neuron_type=neuron_type, trace_ids=specific_trace_ids, parameters=parameters)

# %%
tmp_spiking = dict()
for trace_id in common_per_experiment:
    plotit = False
    plt.figure()
    for experiment_name in experiments:
        vsoma_per_trace_id = data_per_experiment[experiment_name].get_voltage(neuron_id=trace_id).T[0] *1e3
        if cs[experiment_name]=="black":
            if np.max(vsoma_per_trace_id) > -45:
                plotit = True
            else:
                pass
        if plotit:  
            
            if trace_id in frequency_analysis_dict_dspn[experiment_name]:
                    freq = frequency_analysis_dict_dspn[experiment_name][trace_id]
            elif trace_id in frequency_analysis_dict_ispn[experiment_name]:
                freq = frequency_analysis_dict_ispn[experiment_name][trace_id]
                
            if trace_id not in tmp_spiking:
                tmp_spiking.update({trace_id: {experiment_name: freq}})
                
            else:
                tmp_spiking[trace_id].update({experiment_name: freq})
                
            plt.plot(vsoma_per_trace_id, c=cs[experiment_name])
    plt.show()

# %%
d = {"response": list(), "frequency_difference": list()}

# %%
for trace_id in tmp_spiking:
    d["response"].append("shunting")
    frequency_difference = (tmp_spiking[trace_id]['p1_with_ex_current_injection_presynaptic'] - tmp_spiking[trace_id]['p1_with_ex'])/tmp_spiking[trace_id]['p1_with_ex']
    d["frequency_difference"].append(frequency_difference)
df = pd.DataFrame(data=d)

# %%
csfont = {"fontname": "Arial", 'fontsize': 16}
plt.figure(figsize=(8, 6))
sns.violinplot(x="response", y="frequency_difference", data=df)
sns.stripplot(x="response", y="frequency_difference", data=df,
              color="black", edgecolor="gray")

plt.ylabel("Change ratio", **csfont)
plt.yticks(fontsize=14)
# Out:
# (array([-1.1, -1. , -0.9, -0.8, -0.7, -0.6, -0.5]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
d = {"response": list(), "frequency": list()}

# %%
for trace_id in tmp_spiking:
    for e in tmp_spiking[trace_id]:
        d["response"].append(e)
        frequency = tmp_spiking[trace_id][e]
        d["frequency"].append(frequency)
df = pd.DataFrame(data=d)

# %%
cs = {"p1_with_ex": 'grey', 
      "p1_with_ex_current_injection_presynaptic": 'red'}

# %%
csfont = {"fontname": "Arial", 'fontsize': 16}
plt.figure(figsize=(8, 6))
sns.violinplot(x="response", y="frequency", data=df, palette=cs)

for trace_id in tmp_spiking:
    plt.scatter([0,1],[tmp_spiking[trace_id]['p1_with_ex'], tmp_spiking[trace_id]['p1_with_ex_current_injection_presynaptic']], c="black")
    plt.plot([0,1], [tmp_spiking[trace_id]['p1_with_ex'], tmp_spiking[trace_id]['p1_with_ex_current_injection_presynaptic']], c="black")
plt.ylabel("Frequency (Hz)", **csfont)
plt.yticks(fontsize=14)
plt.xticks(fontsize=14)
plt.savefig(os.path.join("spiking_shunting","shunting_spiking_compared.svg"))
