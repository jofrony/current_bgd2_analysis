# %%
import sys
import os
sys.path.append(os.environ["CODE_REPOSITORY"])
from code_repository.excitatory_input.analyse_single_synapse import *

# %%
import os

network_path = os.path.join("networks", "ispn_network")

simulations = dict(network_path=network_path,
                   data=os.path.join(network_path, "simulation", "network-voltage-normal-5-microns.hdf5"),
                   metadata=os.path.join(network_path, "result-normal-5-microns.json"))

tmp = analyse(simulations=simulations)
# Out:
# Loading networks/ispn_network/simulation/network-voltage-normal-5-microns.hdf5
# [2000, 5999, 10000, 14000, 18000]
# [2000, 5999, 10000]
# [2000, 5999, 10000]
# [2000, 5999, 10000, 14000]

# %%
plot(tmp=tmp)

# %%
plot_2(tmp=tmp)
